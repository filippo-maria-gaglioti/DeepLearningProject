# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
percorso_file = 'C:\\Users\\pippo\\OneDrive\\Desktop\\Tesi\\investimenti.xlsx'
df = pd.read_excel(percorso_file)
df.columns
# Out:
# Index(['idprotocollo', 'dataoraincidente', 'anno', 'num_morti', 'num_feriti',
#        'num_riservata', 'feriti_totali', 'num_illesi', 'num_veicoli',
#        'costo_sociale', 'x', 'y', 'municipio13', 'strada1', 'strada2',
#        'strada12', 'localizzazione1', 'localizzazione2', 'strada02',
#        'chilometrica', 'daspecificare', 'impiantosemaforico',
#        'noteimpiantosemaforico', 'tronco', 'particolaritastrada', 'tipostrada',
#        'pavimentazione', 'segnaletica', 'fondostradale',
#        'condizioneatmosferica', 'traffico', 'visibilita', 'illuminazione',
#        'naturaincidente'],
#       dtype='object')

# %%
################# NUMERO RIGHE TOTALI DEL DATAFRAME #########################################################

num_rows = df.shape[0]

print("Il numero totale di righe nel DataFrame è:", num_rows)
# Out:
# Il numero totale di righe nel DataFrame è: 19227

# %%
##### DIVIDERE ORA E DATA INCIDENTE E FARE DUE COLONNE SEPARATE ########

df['dataoraincidente'] = df['dataoraincidente'].astype(str)
df[['data_incidente', 'ora_incidente']] = df['dataoraincidente'].str.split(' ', 1, expand=True)

colonne_da_spostare=df.columns[-2:]
for colonna in colonne_da_spostare[::-1]:
    df.insert(0, colonna, df.pop(colonna))
    
#ELIMINARE COLONNE SUPERFLUE############    
df = df.drop('idprotocollo', axis=1)
df= df.drop('dataoraincidente', axis=1)

df.head(100)
# Out:
#    data_incidente ora_incidente  anno  num_morti  num_feriti  num_riservata  \
# 0      2017-02-13      18:30:00  2017          0           1              0
# 1      2020-11-19      17:40:00  2020          0           0              0
# 2      2016-11-14      11:35:00  2016          0           1              0
# 3      2018-06-22      08:15:00  2018          0           0              0
# 4      2019-12-12      19:00:00  2019          0           1              0
# ..            ...           ...   ...        ...         ...            ...
# 95     2020-12-09      12:10:00  2020          0           1              0
# 96     2011-08-18      21:50:00  2011          0           2              0
# 97     2011-03-09      15:00:00  2011          0           1              0
# 98     2016-04-19      13:10:00  2016          0           1              0
# 99     2011-10-25      10:50:00  2011          0           1              0
#
#     feriti_totali  num_illesi  num_veicoli  costo_sociale  ...  \
# 0               1           1            1          53205  ...
# 1               0           2            1          10986  ...
# 2               1           1            1          53205  ...
# 3               0           2            1          10986  ...
# 4               1           2            1          53205  ...
# ..            ...         ...          ...            ...  ...
# 95              1           2            1          53205  ...
# 96              2           0            1          95424  ...
# 97              1           1            1          53205  ...
# 98              1           3            1          53205  ...
# 99              1           3            1          53205  ...
#
#            particolaritastrada                               tipostrada  \
# 0                   Rettilineo                          Due carreggiate
# 1                     Incrocio  Una carreggiata a senso unico di marcia
# 2   Intersezione semaforizzata           Una carreggiata a doppio senso
# 3                   Rettilineo           Una carreggiata a doppio senso
# 4                   Rettilineo                          Due carreggiate
# ..                         ...                                      ...
# 95                  Rettilineo           Una carreggiata a doppio senso
# 96                  Rettilineo  Una carreggiata a senso unico di marcia
# 97                   Rotatoria           Una carreggiata a doppio senso
# 98                  Rettilineo  Una carreggiata a senso unico di marcia
# 99                  Rettilineo                          Due carreggiate
#
#            pavimentazione               segnaletica      fondostradale  \
# 0               Asfaltata               Orizzontale           Asciutto
# 1               Asfaltata  Verticale ed orizzontale           Asciutto
# 2   In cubetti di porfido  Verticale ed orizzontale           Asciutto
# 3               Asfaltata  Verticale ed orizzontale           Asciutto
# 4               Asfaltata  Verticale ed orizzontale  Bagnato (pioggia)
# ..                    ...                       ...                ...
# 95              Asfaltata  Verticale ed orizzontale  Bagnato (pioggia)
# 96              Asfaltata                 Verticale           Asciutto
# 97              Asfaltata               Orizzontale           Asciutto
# 98              Asfaltata               Orizzontale           Asciutto
# 99              Asfaltata               Orizzontale           Asciutto
#
#    condizioneatmosferica traffico visibilita illuminazione  \
# 0                 Sereno  Normale      Buona   Sufficiente
# 1                 Sereno  Normale      Buona           NaN
# 2               Nuvoloso  Normale      Buona    Ore Diurne
# 3                 Sereno  Normale      Buona    Ore Diurne
# 4        Pioggia in atto  Normale      Buona   Sufficiente
# ..                   ...      ...        ...           ...
# 95              Nuvoloso  Normale      Buona           NaN
# 96                Sereno  Normale      Buona   Sufficiente
# 97                Sereno  Normale      Buona    Ore Diurne
# 98                Sereno  Normale      Buona    Ore Diurne
# 99                Sereno  Normale      Buona    Ore Diurne
#
#            naturaincidente
# 0   Investimento di pedone
# 1   Investimento di pedone
# 2   Investimento di pedone
# 3   Investimento di pedone
# 4   Investimento di pedone
# ..                     ...
# 95  Investimento di pedone
# 96  Investimento di pedone
# 97  Investimento di pedone
# 98  Investimento di pedone
# 99  Investimento di pedone
#
# [100 rows x 34 columns]

# %%
####### AGGIUNTA COLONNA GIORNO DELLA SETTIMANA ###############

def giorno_settimana_da_data(data_stringa):
    data = datetime.strptime(data_stringa, '%Y-%m-%d')
    return data.strftime('%A')

df['giorno_settimana'] = df['data_incidente'].apply(giorno_settimana_da_data)
indice_colonna_data = df.columns.get_loc('data_incidente')
df.insert(indice_colonna_data + 1, 'giorno_settimana', df.pop('giorno_settimana'))
df.head(100)
# Out:
#    data_incidente giorno_settimana ora_incidente  anno  num_morti  num_feriti  \
# 0      2017-02-13           Monday      18:30:00  2017          0           1
# 1      2020-11-19         Thursday      17:40:00  2020          0           0
# 2      2016-11-14           Monday      11:35:00  2016          0           1
# 3      2018-06-22           Friday      08:15:00  2018          0           0
# 4      2019-12-12         Thursday      19:00:00  2019          0           1
# ..            ...              ...           ...   ...        ...         ...
# 95     2020-12-09        Wednesday      12:10:00  2020          0           1
# 96     2011-08-18         Thursday      21:50:00  2011          0           2
# 97     2011-03-09        Wednesday      15:00:00  2011          0           1
# 98     2016-04-19          Tuesday      13:10:00  2016          0           1
# 99     2011-10-25          Tuesday      10:50:00  2011          0           1
#
#     num_riservata  feriti_totali  num_illesi  num_veicoli  ...  \
# 0               0              1           1            1  ...
# 1               0              0           2            1  ...
# 2               0              1           1            1  ...
# 3               0              0           2            1  ...
# 4               0              1           2            1  ...
# ..            ...            ...         ...          ...  ...
# 95              0              1           2            1  ...
# 96              0              2           0            1  ...
# 97              0              1           1            1  ...
# 98              0              1           3            1  ...
# 99              0              1           3            1  ...
#
#            particolaritastrada                               tipostrada  \
# 0                   Rettilineo                          Due carreggiate
# 1                     Incrocio  Una carreggiata a senso unico di marcia
# 2   Intersezione semaforizzata           Una carreggiata a doppio senso
# 3                   Rettilineo           Una carreggiata a doppio senso
# 4                   Rettilineo                          Due carreggiate
# ..                         ...                                      ...
# 95                  Rettilineo           Una carreggiata a doppio senso
# 96                  Rettilineo  Una carreggiata a senso unico di marcia
# 97                   Rotatoria           Una carreggiata a doppio senso
# 98                  Rettilineo  Una carreggiata a senso unico di marcia
# 99                  Rettilineo                          Due carreggiate
#
#            pavimentazione               segnaletica      fondostradale  \
# 0               Asfaltata               Orizzontale           Asciutto
# 1               Asfaltata  Verticale ed orizzontale           Asciutto
# 2   In cubetti di porfido  Verticale ed orizzontale           Asciutto
# 3               Asfaltata  Verticale ed orizzontale           Asciutto
# 4               Asfaltata  Verticale ed orizzontale  Bagnato (pioggia)
# ..                    ...                       ...                ...
# 95              Asfaltata  Verticale ed orizzontale  Bagnato (pioggia)
# 96              Asfaltata                 Verticale           Asciutto
# 97              Asfaltata               Orizzontale           Asciutto
# 98              Asfaltata               Orizzontale           Asciutto
# 99              Asfaltata               Orizzontale           Asciutto
#
#    condizioneatmosferica traffico visibilita illuminazione  \
# 0                 Sereno  Normale      Buona   Sufficiente
# 1                 Sereno  Normale      Buona           NaN
# 2               Nuvoloso  Normale      Buona    Ore Diurne
# 3                 Sereno  Normale      Buona    Ore Diurne
# 4        Pioggia in atto  Normale      Buona   Sufficiente
# ..                   ...      ...        ...           ...
# 95              Nuvoloso  Normale      Buona           NaN
# 96                Sereno  Normale      Buona   Sufficiente
# 97                Sereno  Normale      Buona    Ore Diurne
# 98                Sereno  Normale      Buona    Ore Diurne
# 99                Sereno  Normale      Buona    Ore Diurne
#
#            naturaincidente
# 0   Investimento di pedone
# 1   Investimento di pedone
# 2   Investimento di pedone
# 3   Investimento di pedone
# 4   Investimento di pedone
# ..                     ...
# 95  Investimento di pedone
# 96  Investimento di pedone
# 97  Investimento di pedone
# 98  Investimento di pedone
# 99  Investimento di pedone
#
# [100 rows x 35 columns]

# %%
##########  CATEGORIZZAZIONE ORARIO SERA; MATTIN; NOTTE #############


def categorize_momento_giornata(ora):
    ora = int(ora.split(':')[0])
    if 6 <= ora < 14:
        return 'Mattina'
    elif 14 <= ora < 18:
        return 'Pomeriggio'
    elif 18 <= ora < 23:
        return 'Sera'
    else:
        return 'Notte'

df['momento_giornata'] = df['ora_incidente'].apply(categorize_momento_giornata)

indice_colonna_ora_incidente = df.columns.get_loc('ora_incidente')
df.insert(indice_colonna_ora_incidente + 1, 'momento_giornata', df.pop('momento_giornata'))

df.head(100)
# Out:
#    data_incidente giorno_settimana ora_incidente momento_giornata  anno  \
# 0      2017-02-13           Monday      18:30:00             Sera  2017
# 1      2020-11-19         Thursday      17:40:00       Pomeriggio  2020
# 2      2016-11-14           Monday      11:35:00          Mattina  2016
# 3      2018-06-22           Friday      08:15:00          Mattina  2018
# 4      2019-12-12         Thursday      19:00:00             Sera  2019
# ..            ...              ...           ...              ...   ...
# 95     2020-12-09        Wednesday      12:10:00          Mattina  2020
# 96     2011-08-18         Thursday      21:50:00             Sera  2011
# 97     2011-03-09        Wednesday      15:00:00       Pomeriggio  2011
# 98     2016-04-19          Tuesday      13:10:00          Mattina  2016
# 99     2011-10-25          Tuesday      10:50:00          Mattina  2011
#
#     num_morti  num_feriti  num_riservata  feriti_totali  num_illesi  ...  \
# 0           0           1              0              1           1  ...
# 1           0           0              0              0           2  ...
# 2           0           1              0              1           1  ...
# 3           0           0              0              0           2  ...
# 4           0           1              0              1           2  ...
# ..        ...         ...            ...            ...         ...  ...
# 95          0           1              0              1           2  ...
# 96          0           2              0              2           0  ...
# 97          0           1              0              1           1  ...
# 98          0           1              0              1           3  ...
# 99          0           1              0              1           3  ...
#
#            particolaritastrada                               tipostrada  \
# 0                   Rettilineo                          Due carreggiate
# 1                     Incrocio  Una carreggiata a senso unico di marcia
# 2   Intersezione semaforizzata           Una carreggiata a doppio senso
# 3                   Rettilineo           Una carreggiata a doppio senso
# 4                   Rettilineo                          Due carreggiate
# ..                         ...                                      ...
# 95                  Rettilineo           Una carreggiata a doppio senso
# 96                  Rettilineo  Una carreggiata a senso unico di marcia
# 97                   Rotatoria           Una carreggiata a doppio senso
# 98                  Rettilineo  Una carreggiata a senso unico di marcia
# 99                  Rettilineo                          Due carreggiate
#
#            pavimentazione               segnaletica      fondostradale  \
# 0               Asfaltata               Orizzontale           Asciutto
# 1               Asfaltata  Verticale ed orizzontale           Asciutto
# 2   In cubetti di porfido  Verticale ed orizzontale           Asciutto
# 3               Asfaltata  Verticale ed orizzontale           Asciutto
# 4               Asfaltata  Verticale ed orizzontale  Bagnato (pioggia)
# ..                    ...                       ...                ...
# 95              Asfaltata  Verticale ed orizzontale  Bagnato (pioggia)
# 96              Asfaltata                 Verticale           Asciutto
# 97              Asfaltata               Orizzontale           Asciutto
# 98              Asfaltata               Orizzontale           Asciutto
# 99              Asfaltata               Orizzontale           Asciutto
#
#    condizioneatmosferica traffico visibilita illuminazione  \
# 0                 Sereno  Normale      Buona   Sufficiente
# 1                 Sereno  Normale      Buona           NaN
# 2               Nuvoloso  Normale      Buona    Ore Diurne
# 3                 Sereno  Normale      Buona    Ore Diurne
# 4        Pioggia in atto  Normale      Buona   Sufficiente
# ..                   ...      ...        ...           ...
# 95              Nuvoloso  Normale      Buona           NaN
# 96                Sereno  Normale      Buona   Sufficiente
# 97                Sereno  Normale      Buona    Ore Diurne
# 98                Sereno  Normale      Buona    Ore Diurne
# 99                Sereno  Normale      Buona    Ore Diurne
#
#            naturaincidente
# 0   Investimento di pedone
# 1   Investimento di pedone
# 2   Investimento di pedone
# 3   Investimento di pedone
# 4   Investimento di pedone
# ..                     ...
# 95  Investimento di pedone
# 96  Investimento di pedone
# 97  Investimento di pedone
# 98  Investimento di pedone
# 99  Investimento di pedone
#
# [100 rows x 36 columns]

# %%
# Supponiamo che il tuo dataframe si chiami 'df'

# Sostituisci tutte le occorrenze di "Più di due carreggiate" con "Più di due carreggiate"
df['tipostrada'] = df['tipostrada'].replace('PiÃ¹ di due carreggiate', 'Più di due carreggiate')

# Ora puoi procedere con il resto dell'analisi o la visualizzazione dei dati

# %%
######################## NUMERO DI VALORI DISTINTI PER OGNI COLONNA #############################################

distinct_counts = df.nunique()
distinct_counts
# Out:
# data_incidente             3531
# giorno_settimana              7
# ora_incidente               556
# momento_giornata              4
# anno                         10
# num_morti                     3
# num_feriti                    7
# num_riservata                 3
# feriti_totali                 8
# num_illesi                   10
# num_veicoli                   7
# costo_sociale                14
# x                         16696
# y                         16696
# municipio13                  15
# strada1                    3524
# strada2                    2568
# strada12                   6052
# localizzazione1               9
# localizzazione2               5
# strada02                   2600
# chilometrica               2003
# daspecificare              3613
# impiantosemaforico            4
# noteimpiantosemaforico       23
# tronco                        8
# particolaritastrada          20
# tipostrada                    5
# pavimentazione               10
# segnaletica                   5
# fondostradale                10
# condizioneatmosferica         9
# traffico                      3
# visibilita                    3
# illuminazione                 4
# naturaincidente               1
# dtype: int64

# %%
############################ NUMERO VALORI DISTINTI ########################
count_values = df['strada1'].value_counts()

print("Numero di valori distinti nella colonna 'strada1':", len(count_values))
print("\nValori e rispettive frequenze:")
print(count_values)
# Out:
# Numero di valori distinti nella colonna 'strada1': 3524
#
# Valori e rispettive frequenze:
# VIA CASILINA                  329
# VIA TIBURTINA                 328
# VIA TUSCOLANA                 270
# VIA CASSIA                    259
# VIA PRENESTINA                245
#                              ...
# VIA GIOVANNI FALDELLA           1
# PIAZZA DEL MONTE DI PIETA'      1
# VIA MECENATE                    1
# VIA DI FIORANELLO               1
# VIA DI MONTE SACRO              1
# Name: strada1, Length: 3524, dtype: int64

# %%
######################### VALORI CONTENUTI IN OGNI SINGOLO CAMPO #######################################################

print("###### NUMERO MORTI ############")

unique_num_morti = df['num_morti'].unique()

print(unique_num_morti)
print("\n")

print("###### NUMERO FERITI ############")

unique_num_feriti = df['num_feriti'].unique()
print(unique_num_feriti)
print("\n")

print("###### NUMERO VEICOLI ############")

unique_num_veicoli = df['num_veicoli'].unique()
print(unique_num_veicoli)
print("\n")

print("###### NUMERO MUNICIPIO ############")

unique_municipio13 = df['municipio13'].unique()
print(unique_municipio13)
print("\n")

print("###### NUMERO IMPIANTOSEMAFORICO ############")

unique_impianto_semaforico  = df['impiantosemaforico'].unique()
print(unique_impianto_semaforico)
print("\n")

print("###### NUMERO NOTEIMPIANTOSEMAFORICO ############")

unique_noteimpiantosemaforico = df['noteimpiantosemaforico'].unique()
print(unique_noteimpiantosemaforico)
print("\n")

print("###### NUMERO TIPOSTRADA ############")

unique_tipostrada= df['tipostrada'].unique()
print(unique_tipostrada)
print("\n")

print("###### NUMERO PAVIMENTAZIONE ############")

unique_pavimentazione= df['pavimentazione'].unique()
print(unique_pavimentazione)
print("\n")

print("###### NUMERO SEGNALETICA ############")

unique_segnaletica = df['segnaletica'].unique()
print(unique_segnaletica)
print("\n")

print("###### NUMERO FONDOSTRADALE ############")

unique_fondostradale = df['fondostradale'].unique()
print(unique_fondostradale)
print("\n")

print("###### NUMERO TRAFFICO ############")

unique_traffico = df['traffico'].unique()
print(unique_traffico)
print("\n")

print("###### NUMERO VISIBILITA' ############")

unique_visibilita = df['visibilita'].unique()
print(unique_visibilita)
print("\n")

print("###### NUMERO ILLUMINAZIONE ############")

unique_illuminazione = df['illuminazione'].unique()
print(unique_illuminazione)
print("\n")
# Out:
# ###### NUMERO MORTI ############
# [0 1 2]
#
#
# ###### NUMERO FERITI ############
# [1 0 2 3 4 5 9]
#
#
# ###### NUMERO VEICOLI ############
# [1 2 0 3 4 5 6]
#
#
# ###### NUMERO MUNICIPIO ############
# [ 5.  7.  1.  9. 10.  2. 13.  3. 12.  8. 14.  6.  4. 15. 11. nan]
#
#
# ###### NUMERO IMPIANTOSEMAFORICO ############
# [nan 'Funzionante regolarmente' 'Funzionante su giallo intermittente'
#  'Funzionante irregolarmente' 'Completamente spento']
#
#
# ###### NUMERO NOTEIMPIANTOSEMAFORICO ############
# [nan 'lanterna pedonale: rosso spento'
#  'LA LAMPADA DEL ROSSO PEDONALE POSTO AL CENTRO DELLO SPARTITRAFDFICO PÃ¹FRONTE CIV. 45 DI VIA GRAF NON Ã¨ FUNZIONANTE AL MOMENTO DEI RILIEVI DEL SINISTRO. '
#  'Erano spente le lanterne verdi del ripetitore e del semaforo pedonale posti su via Casilina per la direzione Roma Centro.'
#  'luce rossa lanterna pedonale a chiamata inefficiente su attraversamento carreggiata Via Salaria direzione Roma centro da destra verso sinistra secondo il senso di marcia.'
#  'il semaforo pedonale su via Tuscolana prossimitÃ\xa0 civico 199 ha la luce rossa spenta'
#  "verde sull'impianto semaforico di sinistra di Via Melloni per i veicoli"
#  'ROSSO PEDONALE NON FUNZIONANTE'
#  'rosso pedonale non funzionante solo su palo adiacente al civico 11 di Viale Pretoriano'
#  "lampada rossa spenta dell'impianto semaforico basso"
#  'verde pedonale spento per chi attraversa via B. Franklin (lato mercato) direzione Lgtevere Testaccio.'
#  'Semaforo pedonale aveva luce rossa non funzionante.'
#  'lampade indicanti il passaggio pedonali spente'
#  'la lanterna rossa pedonale, posta sulla palina semaforica antistante il civ. 2 era spenta.'
#  'lampada  "rosso" spenta del pedonale posto all\'algolo di Piazza Vimercati / Via G. Prina '
#  "Il semaforo aveva il verde spento in direzione di via dei Gordiani. Si precisa che l'impianto Ã¨ dotato di giraffa regolarmente funzionante."
#  'il rosso pedonale risulta spento su via siria x c.ne appia lato numeri dispari'
#  'il semaforo pedonale che da Via Settembrini a Via Avezzana non funzionante regolarmente'
#  "la lampada semaforica dell' attraversamento pedonale presenta avarial uce rossa non funzionante."
#  'Gli impianti semaforici posti alla detta intersezione sono funzionanti regolarmente per la carreggiata di Via Casilina in direzione Roma centro, mentre per quanto riguarda i due impianti semaforici posti ai lati destri di ciascuna carreggiata, ossia i due semafori pedonali, quello posto adiacente alla carreggiata di Via Casilina direzione Roma centro risulta funzionante regolarmente, mentre quello posto adiacente alla carrggiata di Via Casilina direzione fuori Roma risulta funzionante regolarmente nella proiezione delle luci gialla e verde, ma non funzionante ossia spento quando invece sarebbe rosso.'
#  '.'
#  'la giraffa semaforica su Via Nomentana, provenienza Roma centro direzione Fonte Nuova, non segnala luce verde. Anomalia segnalata alla C.O. IV Gruppo.'
#  'lampada indicante rosso per i pedoni che attraversano da destra verso sinistra secondo la direzione di marcia dei veicoli diretti verso V/le Trastevere, Ã© spenta.'
#  'la palina semaforica presente su Via Leon Pancaldo ha il verde spento pedonale.']
#
#
# ###### NUMERO TIPOSTRADA ############
# ['Due carreggiate' 'Una carreggiata a senso unico di marcia'
#  'Una carreggiata a doppio senso' 'Più di due carreggiate'
#  'Una carreggiata a senso unico alternato' nan]
#
#
# ###### NUMERO PAVIMENTAZIONE ############
# ['Asfaltata' 'In cubetti di porfido' 'Acciotolata'
#  'Strada pavimentata dissestata' 'Lastricata' nan 'Inghiaiata' 'Sterrata'
#  'Con buche' 'In conglomerato cementizio' 'Bitumata']
#
#
# ###### NUMERO SEGNALETICA ############
# ['Orizzontale' 'Verticale ed orizzontale' 'Verticale' 'Assente'
#  'Temporanea di cantiere' nan]
#
#
# ###### NUMERO FONDOSTRADALE ############
# ['Asciutto' 'Bagnato (pioggia)' 'Bagnato (umiditÃ\xa0 in atto)'
#  'Bagnato (brina)' nan 'Sdrucciolevole (pietrisco)' 'Ghiacciato'
#  'Viscido da liquidi oleosi' 'Sdrucciolevole (fango)'
#  'Sdrucciolevole (terriccio)' 'Con neve']
#
#
# ###### NUMERO TRAFFICO ############
# ['Normale' 'Scarso' 'Intenso' nan]
#
#
# ###### NUMERO VISIBILITA' ############
# ['Buona' 'Sufficiente' 'Insufficiente' nan]
#
#
# ###### NUMERO ILLUMINAZIONE ############
# ['Sufficiente' nan 'Ore Diurne' 'Insufficiente' 'Inesistente']

# %%
################################## NUMERO DI VALORI NULLI PER CAMPO ###################################################

# Count the number of null values for each field
null_counts = df.isnull().sum()

print(null_counts)
# Out:
# data_incidente                0
# giorno_settimana              0
# ora_incidente                 0
# momento_giornata              0
# anno                          0
# num_morti                     0
# num_feriti                    0
# num_riservata                 0
# feriti_totali                 0
# num_illesi                    0
# num_veicoli                   0
# costo_sociale                 0
# x                           249
# y                           249
# municipio13                 337
# strada1                       0
# strada2                   14112
# strada12                      0
# localizzazione1               0
# localizzazione2               0
# strada02                   3900
# chilometrica               9015
# daspecificare             15327
# impiantosemaforico        17796
# noteimpiantosemaforico    19203
# tronco                        1
# particolaritastrada          20
# tipostrada                   20
# pavimentazione               20
# segnaletica                  20
# fondostradale                20
# condizioneatmosferica        20
# traffico                     33
# visibilita                   20
# illuminazione               853
# naturaincidente              20
# dtype: int64

# %%
##################### TIPI PER COLONNE ###########################################

# Get the data types for each column
column_types = df.dtypes

print(column_types)
# Out:
# data_incidente             object
# giorno_settimana           object
# ora_incidente              object
# momento_giornata           object
# anno                        int64
# num_morti                   int64
# num_feriti                  int64
# num_riservata               int64
# feriti_totali               int64
# num_illesi                  int64
# num_veicoli                 int64
# costo_sociale               int64
# x                         float64
# y                         float64
# municipio13               float64
# strada1                    object
# strada2                    object
# strada12                   object
# localizzazione1            object
# localizzazione2            object
# strada02                   object
# chilometrica               object
# daspecificare              object
# impiantosemaforico         object
# noteimpiantosemaforico     object
# tronco                     object
# particolaritastrada        object
# tipostrada                 object
# pavimentazione             object
# segnaletica                object
# fondostradale              object
# condizioneatmosferica      object
# traffico                   object
# visibilita                 object
# illuminazione              object
# naturaincidente            object
# dtype: object

# %%
############### SOSTITUISCI VALORRE Bagnato (umiditÃ in atto) Con Bagnato (umidità in atto) #########################à

# Supponiamo che il tuo DataFrame si chiami 'df'

# Sostituisci tutte le occorrenze di "Bagnato (umiditÃ in atto)" con "Bagnato (umidità in atto)"
df['fondostradale'] = df['fondostradale'].replace('Bagnato (umiditÃ\xa0 in atto)', 'Bagnato(umidità in atto)')

# Ora puoi procedere con il resto dell'analisi o la visualizzazione dei dati

# %%
###################### GRAFICO DISTRIBUZIONE NUMVORTI##############################

# Conta il numero di occorrenze per ciascun valore nella colonna 'num_morti'
count_values = df['num_morti'].value_counts().sort_index()

# Crea il grafico a barre
plt.bar(count_values.index, count_values.values, color='skyblue', edgecolor='black')

# Traccia una linea che collega i punti
plt.plot(count_values.index, count_values.values, marker='o', color='red')

# Aggiungi etichette e titoli
plt.xlabel('Numero di morti')
plt.ylabel('Frequenza')
plt.title('Distribuzione del numero di morti')

# Mostra il grafico
plt.show()

# %%
################ GRAFICO DISTRIBUZIONE NUMERO DI FERITI ###################################

# Conta il numero di occorrenze per ciascun valore nella colonna 'num_feriti'
count_values = df['num_feriti'].value_counts().sort_index()

# Crea il grafico a barre
plt.bar(count_values.index, count_values.values, color='skyblue', edgecolor='black')

# Traccia una linea che collega i punti
plt.plot(count_values.index, count_values.values, marker='o', color='red')

# Aggiungi etichette e titoli
plt.xlabel('Numero di feriti')
plt.ylabel('Frequenza')
plt.title('Distribuzione del numero di feriti')

# Mostra il grafico
plt.show()

# %%
################ GRAFICO DISTRIBUZIONE NUMERO DI VEICOLI ###################################

# Conta il numero di occorrenze per ciascun valore nella colonna 'num_veicoli'
count_values = df['num_veicoli'].value_counts().sort_index()

# Crea il grafico a barre
plt.bar(count_values.index, count_values.values, color='skyblue', edgecolor='black')

# Traccia una linea che collega i punti
plt.plot(count_values.index, count_values.values, marker='o', color='red')

# Aggiungi etichette e titoli
plt.xlabel('Numero di veicoli')
plt.ylabel('Frequenza')
plt.title('Distribuzione del numero di veicoli')

# Mostra il grafico
plt.show()

# %%
########################### GRAFICO DISTRIBUZIONE PER MUNICIPIO13 #########################################àà

# Conta il numero di occorrenze per ciascun municipio nella colonna 'municipio13'
count_values = df['municipio13'].value_counts().sort_index()

# Crea il grafico a linee
plt.plot(count_values.index, count_values.values, marker='o', color='red', linestyle='-')

# Aggiungi etichette e titoli
plt.xlabel('Municipio')
plt.ylabel('Frequenza')
plt.title('Distribuzione per municipio')

# Mostra il grafico
plt.show()

# %%
########################## DISTRIBUZIONE TIPOSTRADA ##########################################

# Conta il numero di occorrenze per ciascun valore nella colonna 'tipostrada'
count_values = df['tipostrada'].value_counts().sort_index()

# Crea il grafico a linee
plt.plot(count_values.index, count_values.values, marker='o', color='red', linestyle='-')

# Aggiungi etichette e titoli
plt.xlabel('Tipo di strada')
plt.ylabel('Frequenza')
plt.title('Distribuzione per tipo di strada')

# Inclina le etichette sull'asse delle ascisse di 45 gradi
plt.xticks(rotation=45)

# Mostra il grafico
plt.show()
